# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from open_ephys.analysis import Session

# Load the session
directory = 'ABATE-008_2025-05-14_14-34-09_001'
session = Session(directory)

print('Pass Initial Test, Moving on to Loading Session...\n')
print(session)
print(session.recordnodes[1].recordings[0])



# Load specific recording
recording = session.recordnodes[1].recordings[0]

# Add sync line and compute global timestamps
recording.add_sync_line(
    1,               # TTL line number
    100,             # processor ID
    'Rhythm Data',   # Stream name (verify this matches your metadata)
    main=True        # Set this stream as reference
)
recording.compute_global_timestamps()

# Extract metadata and global timestamps
metadata = recording.continuous[0].metadata
channel_names = metadata['channel_names']
timestamps = recording.continuous[0].timestamps
data = recording.continuous[0].get_samples(start_sample_index=0, end_sample_index=timestamps.shape[0])
print("Data shape:", data.shape)

# Filter sync events for Line 1
events = recording.events
sync_events = events[
    (events.line == 1) &
    (events.processor_id == 100) &
    (events.stream_name == 'Rhythm Data') &
    (events.state == 1)
]
sync_timestamps = sync_events['timestamp'].to_numpy()

# Load MessageCenter files
messagecenter_dir = os.path.join(directory, "Record Node 111", "experiment1", "recording1", "events", "MessageCenter")
texts = np.load(os.path.join(messagecenter_dir, "text.npy"), allow_pickle=True)
timestamps_msg = np.load(os.path.join(messagecenter_dir, "timestamps.npy"))
sample_numbers = np.load(os.path.join(messagecenter_dir, "sample_numbers.npy"))

# Decode message texts
decoded_texts = [t.decode('utf-8') if isinstance(t, bytes) else str(t) for t in texts]

# Debug print
print(f"Loaded {len(decoded_texts)} MessageCenter entries")
for text, time in zip(decoded_texts, timestamps_msg):
    print(f"[Time: {time:.6f} s] Message: {text}")

# Plot continuous data
fig, axes = plt.subplots(len(channel_names), 1, figsize=(15, 12), sharex=True)

for idx, ax in enumerate(axes):
    ax.plot(timestamps, data[:, idx], label=channel_names[idx])
    for t in sync_timestamps:
        ax.axvline(x=t, color='red', linestyle='--', alpha=0.7, label='Sync Event' if t == sync_timestamps[0] else "")
    ax.set_ylabel('Amplitude (μV)')
    ax.set_title(channel_names[idx])
    ax.grid(True)
    if idx == 0:  # Only annotate messages on topmost plot (Ch5)
        for time, msg in zip(timestamps_msg, decoded_texts):
            ax.axvline(x=time, color='green', linestyle='--', alpha=0.6)
            ax.annotate(
                msg,
                xy=(time, ax.get_ylim()[1]),
                xytext=(time + 0.1, ax.get_ylim()[1] * 1.05),
                rotation=30,  # angled, not vertical
                fontsize=9,
                color='green',
                arrowprops=dict(arrowstyle='->', color='green', lw=1),
                ha='left'
            )

axes[-1].set_xlabel('Time (s)')
plt.tight_layout(rect=[0, 0, 1, 0.97])  # Leave space at top
plt.suptitle('Open Ephys Continuous Data with Sync + MessageCenter Annotations', fontsize=14)
plt.show()

# Optional: standalone sync event plot
plt.figure(figsize=(10, 2))
plt.eventplot(sync_timestamps, orientation='horizontal', colors='red')
plt.title(f'Sync Events on Line 1 - Rhythm Data')
plt.xlabel('Time (s)')
plt.tight_layout()
plt.show()
# Out:
# Pass Initial Test, Moving on to Loading Session...
#
#
# Open Ephys Recording Session Object
# Directory: ABATE-008_2025-05-14_14-34-09_001
#
# <object>.recordnodes:
#   Index 0: Record Node 106 (binary format)
#   Index 1: Record Node 111 (binary format)
#
# Open Ephys GUI Recording
# ID: 0x1d18818d810
# Format: Binary
# Directory: ABATE-008_2025-05-14_14-34-09_001\Record Node 111\experiment1\recording1
# Experiment Index: 0
# Recording Index: 0
# Processor ID: 100, Stream Name: Rhythm Data, Line: 1 (main sync line))
#   First event sample number: 2608253
#   Last event sample number: 23693992
#   Total sync events: 95
#   Sample rate: 20000.0
# Data shape: (21424395, 5)
# Loaded 107 MessageCenter entries
# [Time: 130.389750 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 139.462850 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 145.284600 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 150.166400 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 162.797750 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 198.514650 s] Message: Laster several stims have been at 3 mA. Single Pulse 500us PW
# [Time: 216.603300 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 223.038900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 231.085750 s] Message: Laster several stims have been at 3 mA. Single Pulse 500us PW
# [Time: 262.035900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 269.468950 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 365.081700 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 375.085150 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 386.373750 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 402.007100 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 421.908450 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 525.357050 s] Message: Starting 2.5 mA stimulation
# [Time: 541.680950 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 558.446050 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 563.251150 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 570.175850 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 577.311550 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 587.583500 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 600.723200 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 623.703250 s] Message: 2.0 mA starting now
# [Time: 626.906650 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 636.209950 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 654.394500 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 661.041050 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 664.541750 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 667.610900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 670.641650 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 673.950550 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 677.441700 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 681.345200 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 685.210400 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 693.353150 s] Message: 1.5 mA starting now
# [Time: 698.024000 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 707.499900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 711.508950 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 721.426050 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 727.823250 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 732.503650 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 738.095200 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 741.806950 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 745.950250 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 748.472700 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 751.340400 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 755.196000 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 771.663750 s] Message: 1.0 mA starting now
# [Time: 776.066000 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 785.628250 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 795.324750 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 798.998100 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 802.345400 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 807.169650 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 811.349800 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 815.993400 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 820.549100 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 829.785250 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 835.818000 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 851.815800 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 858.855600 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 869.760600 s] Message: 0.5 mA starting now
# [Time: 881.068400 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 892.098050 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 897.277200 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 902.034300 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 908.585000 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 913.965550 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 921.791800 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 949.653700 s] Message: 0.1 mA starting now
# [Time: 964.980100 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 971.693800 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 978.733600 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 982.713900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 986.559900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 990.319550 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 998.251300 s] Message: 0.1 mA starting now, now with fast settle enabled
# [Time: 1012.330900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1019.869450 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1027.350450 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1092.847450 s] Message: 0.01 mA starting now, now with fast settle enabled
# [Time: 1097.623750 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1103.551000 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1107.790200 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1111.741700 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1115.156100 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1118.273200 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1121.946550 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1124.795100 s] Message: 0.01 mA starting now, now with fast settle disabled
# [Time: 1132.055500 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1139.737900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1142.711100 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1145.492500 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1148.542400 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1151.275850 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1154.268250 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1157.462050 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1160.464050 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1163.888050 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1167.638100 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1171.541650 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1174.936900 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1178.926750 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1184.681350 s] Message: RHDCONTROL TRIGGER 1 100.0
# [Time: 1197.418200 s] Message: Stopping recording and starting new file.

# %%
import matplotlib.pyplot as plt
import numpy as np
from open_ephys.analysis import Session

# Load the session
directory = 'ABATE-008_2025-05-14_14-34-09_001'
session = Session(directory)

print('Pass Initial Test, Moving on to Loading Session...\n')
print(session)
print(session.recordnodes[1].recordings[0])

# Load specific recording
recording = session.recordnodes[1].recordings[0]

# Add sync line and compute global timestamps
recording.add_sync_line(
    1,               # TTL line number
    100,             # processor ID
    'Rhythm Data',   # Stream name (verify this matches your metadata)
    main=True        # Set this stream as reference
)
recording.compute_global_timestamps()

# Extract metadata and global timestamps
metadata = recording.continuous[0].metadata
print(metadata, '\n')
channel_names = metadata['channel_names']
print("Channels:", channel_names, '\n')

# Load continuous data using global timestamps
timestamps = recording.continuous[0].timestamps
n_timestamps = timestamps.shape[0]
data = recording.continuous[0].get_samples(start_sample_index=0, end_sample_index=n_timestamps)
print("Data shape:", data.shape)

# Filter sync events for Line 1
events = recording.events
sync_events = events[
    (events.line == 1) &
    (events.processor_id == 100) &
    (events.stream_name == 'Rhythm Data') &
    (events.state == 1)
]
sync_timestamps = sync_events['timestamp'].to_numpy()

# List all unique TTL events
unique_events = recording.events[['line', 'processor_id', 'stream_name']].drop_duplicates()
print('List all unique TTL events (line, processor_id, stream_name)\n')
print(unique_events, '\n')

# Count how many times each TTL line fires
event_counts = recording.events.groupby(['line', 'processor_id', 'stream_name']).size()
print('Count how many times each TTL line fires\n')
print(event_counts.sort_values(ascending=False), '\n')

# Plot one subplot per channel
fig, axes = plt.subplots(len(channel_names), 1, figsize=(15, 10), sharex=True)

for idx, ax in enumerate(axes):
    ax.plot(timestamps, data[:, idx], label=channel_names[idx])
    for t in sync_timestamps:
        ax.axvline(x=t, color='red', linestyle='--', alpha=0.7, label='Sync Event' if t == sync_timestamps[0] else "")
    ax.set_ylabel('Amplitude (μV)')
    ax.set_title(f"{channel_names[idx]}")
    ax.grid(True)
    ax.legend(loc='upper right')

axes[-1].set_xlabel('Time (s)')
plt.tight_layout()
plt.show()

# ======= NEW: Plot Differential EMG1 - EMG2 =======
emg1 = data[:, 2]  # Assuming channel 2 is EMG1 (CH7)
emg2 = data[:, 3]  # Assuming channel 3 is EMG2 (CH11)
differential_emg = emg1 - emg2

plt.figure(figsize=(15, 4))
plt.plot(timestamps, differential_emg, label="EMG1 - EMG2", color='purple')
plt.axhline(0, color='black', linestyle='--', linewidth=0.5)
plt.title("Differential EMG Signal (EMG1 - EMG2)")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (μV)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()


# ======= COUNT # OF PLOTS =======
# Count total sync events and generated peri-stimulus plots
n_sync_events = len(sync_timestamps)
print(f"\nTotal sync events found (used for peri-stimulus plots): {n_sync_events}")

# Each sync event generates one peri-stimulus plot
print(f"Total peri-stimulus plots generated: {n_sync_events}")

pre_event_time = 5  #define time in ms to plot before the event
post_event_time = 20    #define time in ms to plot after the event

valid_plot_count = 0
for stamp in sync_timestamps:
    stamp_pre = stamp - pre_event_time / 1000
    stamp_end = stamp + post_event_time / 1000
    
    # Skip if outside bounds
    if stamp_pre < timestamps[0] or stamp_end > timestamps[-1]:
        continue
    
    idx_event = np.where(timestamps >= stamp)[0][0]
    idx_start_pre = np.where(timestamps >= stamp_pre)[0][0]
    idx_end = np.where(timestamps >= stamp_end)[0][0]

    event_diff_emg = differential_emg[idx_start_pre:idx_end]
# Out:
# Pass Initial Test, Moving on to Loading Session...
#
#
# Open Ephys Recording Session Object
# Directory: ABATE-008_2025-05-14_14-34-09_001
#
# <object>.recordnodes:
#   Index 0: Record Node 106 (binary format)
#   Index 1: Record Node 111 (binary format)
#
# Open Ephys GUI Recording
# ID: 0x1d19f76ff50
# Format: Binary
# Directory: ABATE-008_2025-05-14_14-34-09_001\Record Node 111\experiment1\recording1
# Experiment Index: 0
# Recording Index: 0
# Processor ID: 100, Stream Name: Rhythm Data, Line: 1 (main sync line))
#   First event sample number: 2608253
#   Last event sample number: 23693992
#   Total sync events: 95
#   Sample rate: 20000.0
# {'source_node_id': 100, 'source_node_name': 'Acquisition Board', 'stream_name': 'Rhythm Data', 'sample_rate': 20000.0, 'num_channels': 5, 'channel_names': ['CH1', 'CH5', 'CH7', 'CH11', 'ADC1'], 'bit_volts': [0.1949999928474426, 0.1949999928474426, 0.1949999928474426, 0.1949999928474426, 0.000152587890625]}
#
# Channels: ['CH1', 'CH5', 'CH7', 'CH11', 'ADC1']
#
# Data shape: (21424395, 5)
# List all unique TTL events (line, processor_id, stream_name)
#
#    line  processor_id  stream_name
# 0     1           100  Rhythm Data
#
# Count how many times each TTL line fires
#
# line  processor_id  stream_name
# 1     100           Rhythm Data    190
# dtype: int64
# C:\Users\dal866445\AppData\Local\Temp\ipykernel_56612\2888305322.py:86: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# c:\Users\dal866445\Documents\Github\open-ephys-python-tools\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Total sync events found (used for peri-stimulus plots): 95
# Total peri-stimulus plots generated: 95

# %%
metadata
metadata['sample_rate']
stamp

# %%
import numpy as np

file_path = r"ABATE-008_2025-05-14_14-34-09_001\Record Node 106\experiment1\recording4\events\MessageCenter\text.npy"
texts = np.load(file_path, allow_pickle=True)

decoded_texts = [t.decode('utf-8') if isinstance(t, bytes) else str(t) for t in texts]

# Print and modify
for i, msg in enumerate(decoded_texts):
    print(f"{i}: {msg}")
'''decoded_texts[91] = "starting 0.75 mA"
decoded_texts[98] = "starting 0.50 mA"
decoded_texts[104] = "starting 0.40 mA"
decoded_texts[115] = "starting 0.20 mA"
decoded_texts[121] = "starting 0.10 mA"
decoded_texts[127] = "starting 0.08 mA"
decoded_texts[133] = "starting 0.06 mA"
decoded_texts[140] = "starting 0.04 mA"
decoded_texts[146] = "starting 0.02 mA"
decoded_texts[152] = "starting 0.01 mA"
decoded_texts[154] = "starting 1.0 mA"





# Save modified
encoded_texts = np.array([t.encode('utf-8') for t in decoded_texts], dtype=object)
np.save("text_modified.npy", encoded_texts)

#---------------


file_path = r"text_modified.npy"
texts = np.load(file_path, allow_pickle=True)

decoded_texts = [t.decode('utf-8') if isinstance(t, bytes) else str(t) for t in texts]

# Print and modify
for i, msg in enumerate(decoded_texts):
    print(f"{i}: {msg}")

'''
# Out:
# 0: starting new recording
# 1: new cuff, smaller 26ga ground, no neck just mx twitch
# 2: fast settle on
# 3: starting at 0.5 mA
# 4: RHDCONTROL TRIGGER 1 100.0
# 5: RHDCONTROL TRIGGER 1 100.0
# 6: RHDCONTROL TRIGGER 1 100.0
# 7: RHDCONTROL TRIGGER 1 100.0
# 8: RHDCONTROL TRIGGER 1 100.0
# 9: starting at 0.6 mA
# 10: RHDCONTROL TRIGGER 1 100.0
# 11: RHDCONTROL TRIGGER 1 100.0
# 12: RHDCONTROL TRIGGER 1 100.0
# 13: RHDCONTROL TRIGGER 1 100.0
# 14: RHDCONTROL TRIGGER 1 100.0
# 15: starting at 0.7 mA
# 16: RHDCONTROL TRIGGER 1 100.0
# 17: RHDCONTROL TRIGGER 1 100.0
# 18: RHDCONTROL TRIGGER 1 100.0
# 19: RHDCONTROL TRIGGER 1 100.0
# 20: RHDCONTROL TRIGGER 1 100.0
# 21: starting at 0.8 mA
# 22: RHDCONTROL TRIGGER 1 100.0
# 23: RHDCONTROL TRIGGER 1 100.0
# 24: RHDCONTROL TRIGGER 1 100.0
# 25: RHDCONTROL TRIGGER 1 100.0
# 26: RHDCONTROL TRIGGER 1 100.0
# 27: starting at 0.9 mA
# 28: RHDCONTROL TRIGGER 1 100.0
# 29: RHDCONTROL TRIGGER 1 100.0
# 30: RHDCONTROL TRIGGER 1 100.0
# 31: RHDCONTROL TRIGGER 1 100.0
# 32: RHDCONTROL TRIGGER 1 100.0
# 33: starting at 1.0 mA
# 34: RHDCONTROL TRIGGER 1 100.0
# 35: RHDCONTROL TRIGGER 1 100.0
# 36: RHDCONTROL TRIGGER 1 100.0
# 37: RHDCONTROL TRIGGER 1 100.0
# 38: RHDCONTROL TRIGGER 1 100.0
# 39: starting at 1.1 mA
# 40: RHDCONTROL TRIGGER 1 100.0
# 41: RHDCONTROL TRIGGER 1 100.0
# 42: RHDCONTROL TRIGGER 1 100.0
# 43: RHDCONTROL TRIGGER 1 100.0
# 44: RHDCONTROL TRIGGER 1 100.0
# 45: RHDCONTROL TRIGGER 1 100.0
# 46: starting at 1.2 mA
# 47: RHDCONTROL TRIGGER 1 100.0
# 48: RHDCONTROL TRIGGER 1 100.0
# 49: RHDCONTROL TRIGGER 1 100.0
# 50: RHDCONTROL TRIGGER 1 100.0
# 51: RHDCONTROL TRIGGER 1 100.0
# 52: starting at 1.3 mA
# 53: RHDCONTROL TRIGGER 1 100.0
# 54: RHDCONTROL TRIGGER 1 100.0
# 55: RHDCONTROL TRIGGER 1 100.0
# 56: RHDCONTROL TRIGGER 1 100.0
# 57: RHDCONTROL TRIGGER 1 100.0
# 58: starting at 1.4 mA
# 59: RHDCONTROL TRIGGER 1 100.0
# 60: RHDCONTROL TRIGGER 1 100.0
# 61: RHDCONTROL TRIGGER 1 100.0
# 62: RHDCONTROL TRIGGER 1 100.0
# 63: RHDCONTROL TRIGGER 1 100.0
# 64: starting at 1.5 mA
# 65: RHDCONTROL TRIGGER 1 100.0
# 66: RHDCONTROL TRIGGER 1 100.0
# 67: RHDCONTROL TRIGGER 1 100.0
# 68: RHDCONTROL TRIGGER 1 100.0
# 69: RHDCONTROL TRIGGER 1 100.0
# 70: starting at 1.6 mA
# 71: RHDCONTROL TRIGGER 1 100.0
# 72: RHDCONTROL TRIGGER 1 100.0
# 73: RHDCONTROL TRIGGER 1 100.0
# 74: RHDCONTROL TRIGGER 1 100.0
# 75: RHDCONTROL TRIGGER 1 100.0
# 76: starting at 1.7 mA
# 77: RHDCONTROL TRIGGER 1 100.0
# 78: RHDCONTROL TRIGGER 1 100.0
# 79: RHDCONTROL TRIGGER 1 100.0
# 80: RHDCONTROL TRIGGER 1 100.0
# 81: RHDCONTROL TRIGGER 1 100.0
# 82: starting at 1.8 mA
# 83: RHDCONTROL TRIGGER 1 100.0
# 84: RHDCONTROL TRIGGER 1 100.0
# 85: RHDCONTROL TRIGGER 1 100.0
# 86: RHDCONTROL TRIGGER 1 100.0
# 87: starting at 1.9 mA
# 88: RHDCONTROL TRIGGER 1 100.0
# 89: RHDCONTROL TRIGGER 1 100.0
# 90: RHDCONTROL TRIGGER 1 100.0
# 91: RHDCONTROL TRIGGER 1 100.0
# 92: RHDCONTROL TRIGGER 1 100.0
# 93: starting at 2.0 mA
# 94: RHDCONTROL TRIGGER 1 100.0
# 95: RHDCONTROL TRIGGER 1 100.0
# 96: RHDCONTROL TRIGGER 1 100.0
# 97: RHDCONTROL TRIGGER 1 100.0
# 98: RHDCONTROL TRIGGER 1 100.0
# 99: starting at 2.1 mA
# 100: RHDCONTROL TRIGGER 1 100.0
# 101: RHDCONTROL TRIGGER 1 100.0
# 102: RHDCONTROL TRIGGER 1 100.0
# 103: RHDCONTROL TRIGGER 1 100.0
# 104: RHDCONTROL TRIGGER 1 100.0
# 105: starting at 2.2 mA
# 106: RHDCONTROL TRIGGER 1 100.0
# 107: RHDCONTROL TRIGGER 1 100.0
# 108: RHDCONTROL TRIGGER 1 100.0
# 109: RHDCONTROL TRIGGER 1 100.0
# 110: RHDCONTROL TRIGGER 1 100.0
# 111: starting at 2.3 mA
# 112: RHDCONTROL TRIGGER 1 100.0
# 113: RHDCONTROL TRIGGER 1 100.0
# 114: RHDCONTROL TRIGGER 1 100.0
# 115: RHDCONTROL TRIGGER 1 100.0
# 116: RHDCONTROL TRIGGER 1 100.0
# 117: starting at 2.4 mA
# 118: RHDCONTROL TRIGGER 1 100.0
# 119: RHDCONTROL TRIGGER 1 100.0
# 120: RHDCONTROL TRIGGER 1 100.0
# 121: RHDCONTROL TRIGGER 1 100.0
# 122: RHDCONTROL TRIGGER 1 100.0
# 123: starting at 2.5 mA
# 124: RHDCONTROL TRIGGER 1 100.0
# 125: RHDCONTROL TRIGGER 1 100.0
# 126: RHDCONTROL TRIGGER 1 100.0
# 127: RHDCONTROL TRIGGER 1 100.0
# 128: RHDCONTROL TRIGGER 1 100.0
# 129: starting at 2.75 mA
# 130: RHDCONTROL TRIGGER 1 100.0
# 131: RHDCONTROL TRIGGER 1 100.0
# 132: RHDCONTROL TRIGGER 1 100.0
# 133: RHDCONTROL TRIGGER 1 100.0
# 134: RHDCONTROL TRIGGER 1 100.0
# 135: starting at 3.0 mA
# 136: RHDCONTROL TRIGGER 1 100.0
# 137: RHDCONTROL TRIGGER 1 100.0
# 138: RHDCONTROL TRIGGER 1 100.0
# 139: RHDCONTROL TRIGGER 1 100.0
# 140: RHDCONTROL TRIGGER 1 100.0
# 141: starting at 3.25 mA
# 142: RHDCONTROL TRIGGER 1 100.0
# 143: RHDCONTROL TRIGGER 1 100.0
# 144: RHDCONTROL TRIGGER 1 100.0
# 145: RHDCONTROL TRIGGER 1 100.0
# 146: RHDCONTROL TRIGGER 1 100.0
# 147: starting to get saturation warning on CH7
# 148: starting at 3.5 mA
# 149: RHDCONTROL TRIGGER 1 100.0
# 150: RHDCONTROL TRIGGER 1 100.0
# 151: RHDCONTROL TRIGGER 1 100.0
# 152: RHDCONTROL TRIGGER 1 100.0
# 153: RHDCONTROL TRIGGER 1 100.0
# 154: starting at 3.75 mA
# 155: RHDCONTROL TRIGGER 1 100.0
# 156: RHDCONTROL TRIGGER 1 100.0
# 157: RHDCONTROL TRIGGER 1 100.0
# 158: RHDCONTROL TRIGGER 1 100.0
# 159: RHDCONTROL TRIGGER 1 100.0
# 160: starting at 4.0 mA
# 161: RHDCONTROL TRIGGER 1 100.0
# 162: RHDCONTROL TRIGGER 1 100.0
# 163: RHDCONTROL TRIGGER 1 100.0
# 164: RHDCONTROL TRIGGER 1 100.0
# 165: RHDCONTROL TRIGGER 1 100.0
# 166: starting at 4.25 mA
# 167: RHDCONTROL TRIGGER 1 100.0
# 168: RHDCONTROL TRIGGER 1 100.0
# 169: RHDCONTROL TRIGGER 1 100.0
# 170: RHDCONTROL TRIGGER 1 100.0
# 171: RHDCONTROL TRIGGER 1 100.0
# 172: starting at 4.5 mA
# 173: RHDCONTROL TRIGGER 1 100.0
# 174: RHDCONTROL TRIGGER 1 100.0
# 175: RHDCONTROL TRIGGER 1 100.0
# 176: RHDCONTROL TRIGGER 1 100.0
# 177: RHDCONTROL TRIGGER 1 100.0
# 178: starting at 4.75 mA
# 179: RHDCONTROL TRIGGER 1 100.0
# 180: RHDCONTROL TRIGGER 1 100.0
# 181: RHDCONTROL TRIGGER 1 100.0
# 182: RHDCONTROL TRIGGER 1 100.0
# 183: RHDCONTROL TRIGGER 1 100.0
# 184: starting at 5.0 mA
# 185: RHDCONTROL TRIGGER 1 100.0
# 186: RHDCONTROL TRIGGER 1 100.0
# 187: RHDCONTROL TRIGGER 1 100.0
# 188: RHDCONTROL TRIGGER 1 100.0
# 189: RHDCONTROL TRIGGER 1 100.0
# 190: starting at 5.25 mA
# 191: RHDCONTROL TRIGGER 1 100.0
# 192: RHDCONTROL TRIGGER 1 100.0
# 193: RHDCONTROL TRIGGER 1 100.0
# 194: RHDCONTROL TRIGGER 1 100.0
# 195: RHDCONTROL TRIGGER 1 100.0
# 196: starting at 5.5 mA
# 197: RHDCONTROL TRIGGER 1 100.0
# 198: RHDCONTROL TRIGGER 1 100.0
# 199: RHDCONTROL TRIGGER 1 100.0
# 200: RHDCONTROL TRIGGER 1 100.0
# 201: RHDCONTROL TRIGGER 1 100.0
# 202: starting at 5.75 mA
# 203: RHDCONTROL TRIGGER 1 100.0
# 204: RHDCONTROL TRIGGER 1 100.0
# 205: RHDCONTROL TRIGGER 1 100.0
# 206: RHDCONTROL TRIGGER 1 100.0
# 207: RHDCONTROL TRIGGER 1 100.0
# 208: starting at 6.0 mA
# 209: RHDCONTROL TRIGGER 1 100.0
# 210: RHDCONTROL TRIGGER 1 100.0
# 211: RHDCONTROL TRIGGER 1 100.0
# 212: RHDCONTROL TRIGGER 1 100.0
# 213: RHDCONTROL TRIGGER 1 100.0
# 214: stopping recording
# 'decoded_texts[91] = "starting 0.75 mA"\ndecoded_texts[98] = "starting 0.50 mA"\ndecoded_texts[104] = "starting 0.40 mA"\ndecoded_texts[115] = "starting 0.20 mA"\ndecoded_texts[121] = "starting 0.10 mA"\ndecoded_texts[127] = "starting 0.08 mA"\ndecoded_texts[133] = "starting 0.06 mA"\ndecoded_texts[140] = "starting 0.04 mA"\ndecoded_texts[146] = "starting 0.02 mA"\ndecoded_texts[152] = "starting 0.01 mA"\ndecoded_texts[154] = "starting 1.0 mA"\n\n\n\n\n\n# Save modified\nencoded_texts = np.array([t.encode(\'utf-8\') for t in decoded_texts], dtype=object)\nnp.save("text_modified.npy", encoded_texts)\n\n#---------------\n\n\nfile_path = r"text_modified.npy"\ntexts = np.load(file_path, allow_pickle=True)\n\ndecoded_texts = [t.decode(\'utf-8\') if isinstance(t, bytes) else str(t) for t in texts]\n\n# Print and modify\nfor i, msg in enumerate(decoded_texts):\n    print(f"{i}: {msg}")\n\n'
